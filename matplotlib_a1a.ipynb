# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
plt.plot(a1,b1)
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
plt.plot(a1,b1, marker = 'o')
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
plt.plot(a1,b1, marker = 'o', mfc='red', mec= 'black')
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
plt.plot(a1,b1, marker = 'o', mfc='red', mec= 'black', linewidth = 4)
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
plt.plot(a1,b1, marker = 'o',ms=14, mfc='red', mec= 'black', linewidth = 12)
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
c1 = np.array([11,15,17,21,31,81])
plt.plot(a1,b1, marker = 'o',mfc='red', mec= 'black', color='red')
plt.plot(a1,c1, marker = '*',mfc='black', mec= 'red', color = 'green')
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
c1 = np.array([11,15,17,21,31,81])
plt.plot(a1,b1, marker = 'o',mfc='red', mec= 'black', color='red', label='data b1')
plt.plot(a1,c1, marker = '*',mfc='black', mec= 'red', color = 'green', label ='data c1')
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
c1 = np.array([11,15,17,21,31,81])
plt.plot(a1,b1, marker = 'o',mfc='red', mec= 'black', color='red', label='data b1')
plt.plot(a1,c1, marker = '*',mfc='black', mec= 'red', color = 'green', label ='data c1')
plt.legend()
plt.show()

# %%
a1 = np.array([1,3,5,7,9,11])
b1 = np.array([33,44,55,11,33,22])
c1 = np.array([11,15,17,21,31,81])
plt.plot(a1,b1, marker = 'o',mfc='red', mec= 'black', color='red', label='data b1')
plt.plot(a1,c1, marker = '*',mfc='black', mec= 'red', color = 'green', label ='data c1')
plt.legend()
plt.grid(True, color='black')
plt.show()

# %%
a1 = np.array([1,3,22,33,44,21])
b1 = np.array([0,10,20,30,40,50])
plt.hist(a1,b1)
plt.show()

# %%
a1 = np.array([1,3,5,43,4,21,55,13,41,48,49])
b1 = np.array([0,10,20,30,40,50])
plt.hist(a1,b1)
plt.show()

# %%
a1 = np.array([1,3,5,43,4,21,55,13,41,48,49])
b1 = np.array([0,10,20,30,40,50])
plt.hist(a1,b1,color='red')
plt.show()

# %%
a1 = np.array([1,3,5,43,4,21,55,13,41,48,49])
b1 = np.array([0,10,20,30,40,50])
colors = ['red','green','black','blue','black']
plt.hist(a1,b1, color='red')
# plt.hist(a1,b1, color=colors)

plt.show()

# %%
a1 = np.array([10,20,30,40,50])
plt.pie(a1)
# Out:
# ([<matplotlib.patches.Wedge at 0x2709c710510>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, ''),
#   Text(0.7360436312779136, 0.817459340184711, ''),
#   Text(-0.33991877217145816, 1.046162142464278, ''),
#   Text(-1.0759623315431446, -0.2287029975759841, ''),
#   Text(0.5500001932481627, -0.9526278325909777, '')])

# %%
a1 = np.array([10,20,30,40,50])
colors = ['red','green','blue','black','yellow']
plt.pie(a1, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x2709c78e990>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, ''),
#   Text(0.7360436312779136, 0.817459340184711, ''),
#   Text(-0.33991877217145816, 1.046162142464278, ''),
#   Text(-1.0759623315431446, -0.2287029975759841, ''),
#   Text(0.5500001932481627, -0.9526278325909777, '')])

# %%
a1 = np.array([1,3,5,43,4,21])
b1 = np.array([0,10,20,30,40,50])
colors = ['red','green','black','blue','black','red']
plt.bar(a1,b1,color=colors)
plt.show()

# %%
a1 = np.array([10,20,30,40,50])
colors = ['red','green','blue','black','yellow']
labels = ['Nepal',"India","USA","Pak","China"]
plt.pie(a1, colors=colors, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2709d40da10>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'Nepal'),
#   Text(0.7360436312779136, 0.817459340184711, 'India'),
#   Text(-0.33991877217145816, 1.046162142464278, 'USA'),
#   Text(-1.0759623315431446, -0.2287029975759841, 'Pak'),
#   Text(0.5500001932481627, -0.9526278325909777, 'China')])

# %%
a1 = np.array([10,20,30,40,50])
explode = (0,0,0,0.1,0)
colors = ['red','green','blue','black','yellow']
labels = ['Nepal',"India","USA","Pak","China"]
plt.pie(a1, colors=colors, labels=labels, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x2709d5539d0>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'Nepal'),
#   Text(0.7360436312779136, 0.817459340184711, 'India'),
#   Text(-0.33991877217145816, 1.046162142464278, 'USA'),
#   Text(-1.1737770889561576, -0.24949417917380085, 'Pak'),
#   Text(0.5500001932481627, -0.9526278325909777, 'China')])

# %%
a1 = np.array([10,20,30,40,50])
explode = (0,0,0,0.3,0)
colors = ['red','green','blue','black','yellow']
labels = ['Nepal',"India","USA","Pak","China"]
plt.pie(a1, colors=colors, labels=labels, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x2709d588990>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'Nepal'),
#   Text(0.7360436312779136, 0.817459340184711, 'India'),
#   Text(-0.33991877217145816, 1.046162142464278, 'USA'),
#   Text(-1.369406603782184, -0.2910765423694343, 'Pak'),
#   Text(0.5500001932481627, -0.9526278325909777, 'China')])

# %%
a1 = np.array([10,20,30,40,50])
explode = (0.2,0,0,0.1,0)
colors = ['red','green','blue','black','yellow']
labels_n = ['Nepal',"India","USA","Pak","China"]
plt.title="Pie chart demo"
plt.pie(a1, colors=colors, explode=explode, shadow=True, frame=True, labels= labels_n)
plt.legend(loc='upper left')
# shadow=False,
#     labeldistance=1.1,
#     startangle=0,
#     radius=1,
#     counterclock=True,
#     wedgeprops=None,
#     textprops=None,
#     center=(0, 0),
#     frame=False,
#     rotatelabels=False,
#     *,
#     normalize=True,
#     hatch=None,
#     data=None,
