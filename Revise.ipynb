# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'year': [2018,2019,2020,2021,2022],
    'expenses': [45000,50000,42000,40000,43000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    year  expenses
# 0  2018     45000
# 1  2019     50000
# 2  2020     42000
# 3  2021     40000
# 4  2022     43000

# %%
df.columns
# Out:
# Index(['year', 'expenses'], dtype='object')

# %%
plt.bar(df.year,df.expenses)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(df.year,df.expenses, color = 'red')
# Out:
# <BarContainer object of 5 artists>

# %%
sm = df.plot(kind = 'bar', x = 'year', y = 'expenses', legend = False)

# %%
sm = df.plot(kind = 'bar', x = 'year', y = 'expenses', legend = True)

# %%
product = ['noodles', 'fruits','rice', 'oil','veg', 'colth','meat','drink']
sales = [2,5,16,14,15,18,25,22]
plt.bar(product,sales,color = 'red')
# Out:
# <BarContainer object of 8 artists>

# %%
for i, value in enumerate(sales):
    print(i,value)
# Out:
# 0 2
# 1 5
# 2 16
# 3 14
# 4 15
# 5 18
# 6 25
# 7 22

# %%
product = ['noodles', 'fruits','rice', 'oil','veg', 'colth','meat','drink']
sales = [2,5,16,14,15,18,25,22]
plt.bar(product,sales,color = 'red')
for i, value in enumerate(sales):
        plt.text(i,value,str(value), ha = 'center')
        
plt.xlabel('product')
plt.ylabel('sales')
plt.title('estimate sales')
plt.show()

# %%
df
# Out:
#    year  expenses
# 0  2018     45000
# 1  2019     50000
# 2  2020     42000
# 3  2021     40000
# 4  2022     43000

# %%
sm = plt.bar(df.year,df.expenses)
for x, y in zip(df.year, df.expenses):
    plt.text(x,y, str(y), ha = 'center')
    
plt.show()

# %% [markdown]
# histogram

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
x = 168
sig = 5
sample = 200
np.random.seed(0)
height_f = np.random.normal(x,sig,sample).astype(int)

# %%
x1 = 180
sig = 6
sample = 200
np.random.seed(1)
height_m = np.random.normal(x1,sig,sample).astype(int)

# %%
height_f
# Out:
# array([176, 170, 172, 179, 177, 163, 172, 167, 167, 170, 168, 175, 171,
#        168, 170, 169, 175, 166, 169, 163, 155, 171, 172, 164, 179, 160,
#        168, 167, 175, 175, 168, 169, 163, 158, 166, 168, 174, 174, 166,
#        166, 162, 160, 159, 177, 165, 165, 161, 171, 159, 166, 163, 169,
#        165, 162, 167, 170, 168, 169, 164, 166, 164, 166, 163, 159, 168,
#        165, 159, 170, 163, 168, 171, 168, 173, 161, 170, 164, 163, 165,
#        166, 168, 162, 172, 170, 160, 175, 177, 173, 167, 162, 173, 165,
#        174, 169, 172, 169, 171, 168, 176, 168, 170, 177, 161, 161, 172,
#        162, 177, 165, 164, 177, 175, 177, 172, 163, 177, 166, 172, 172,
#        167, 171, 172, 169, 162, 169, 174, 164, 167, 165, 177, 171, 170,
#        164, 170, 164, 168, 164, 171, 170, 166, 169, 162, 160, 170, 168,
#        171, 179, 172, 163, 173, 161, 165, 167, 176, 164, 163, 167, 164,
#        173, 162, 162, 165, 165, 177, 172, 168, 161, 172, 162, 160, 173,
# ...

# %%
height_m
# Out:
# array([189, 176, 176, 173, 185, 166, 190, 175, 181, 178, 188, 167, 178,
#        177, 186, 173, 178, 174, 180, 183, 173, 186, 185, 183, 185, 175,
#        179, 174, 178, 183, 175, 177, 175, 174, 175, 179, 173, 181, 189,
#        184, 178, 174, 175, 190, 180, 176, 181, 192, 180, 183, 181, 177,
#        173, 177, 178, 183, 185, 185, 181, 185, 175, 187, 183, 178, 182,
#        179, 186, 189, 193, 171, 171, 176, 180, 185, 181, 167, 178, 184,
#        181, 184, 178, 178, 181, 182, 181, 180, 175, 182, 180, 186, 187,
#        181, 177, 176, 182, 180, 177, 180, 176, 184, 177, 187, 182, 183,
#        173, 181, 184, 174, 178, 180, 171, 181, 185, 174, 182, 172, 179,
#        170, 186, 182, 179, 175, 187, 191, 168, 187, 189, 182, 172, 185,
#        178, 176, 172, 183, 184, 176, 183, 173, 184, 180, 178, 179, 185,
#        184, 183, 180, 180, 183, 181, 184, 178, 165, 186, 193, 182, 179,
#        179, 179, 180, 173, 176, 174, 181, 178, 182, 178, 185, 181, 193,
# ...

# %%
data = pd.DataFrame({'height_f': height_f,"height_m": height_m})
data
# Out:
#      height_f  height_m
# 0         176       189
# 1         170       176
# 2         172       176
# 3         179       173
# 4         177       185
# ..        ...       ...
# 195       167       170
# 196       171       183
# 197       172       182
# 198       178       184
# 199       174       186
#
# [200 rows x 2 columns]

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   height_f  200 non-null    int32
#  1   height_m  200 non-null    int32
# dtypes: int32(2)
# memory usage: 1.7 KB

# %%
data.describe()
# Out:
#          height_f    height_m
# count  200.000000  200.000000
# mean   167.835000  180.145000
# std      5.130241    5.486757
# min    155.000000  165.000000
# 25%    164.000000  176.750000
# 50%    168.000000  180.000000
# 75%    172.000000  184.000000
# max    179.000000  195.000000

# %%
df1 = data.groupby("height_f").count()
df1
# Out:
#           height_m
# height_f
# 155              1
# 156              1
# 158              1
# 159              5
# 160              5
# 161              8
# 162             13
# 163             11
# 164             15
# 165             12
# 166             11
# 167             11
# 168             17
# 169             13
# 170             13
# 171             12
# 172             16
# 173              6
# 174              5
# 175              7
# 176              3
# 177             10
# 178              1
# 179              3

# %%
df1.plot()
# Out:
# <Axes: xlabel='height_f'>

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'height_f'}>,
#         <Axes: title={'center': 'height_m'}>]], dtype=object)

# %%
 data.hist(bins = 5) #no. of bar
# Out:
# array([[<Axes: title={'center': 'height_f'}>,
#         <Axes: title={'center': 'height_m'}>]], dtype=object)

# %%
data.hist(bins = 3)
# Out:
# array([[<Axes: title={'center': 'height_f'}>,
#         <Axes: title={'center': 'height_m'}>]], dtype=object)

# %%
data.plot.hist(bins = 10)  #comapre by plot
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot.hist(bins = 10, alpha = 0.5)  #comapre by plot
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.read_csv("heart-disease.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
df['target'].value_counts().plot(kind = 'bar', color = ['red','green']);

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
 x = 'target'
y = 'sex'
plt(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 x = 'target'
#       2 y = 'sex'
# ----> 3 plt(x,y)
#
# TypeError: 'module' object is not callable

# %% [markdown]
# finding pattern

# %%
pd.crosstab(df.target,df.sex)
# Out:
# sex      0    1
# target
# 0       24  114
# 1       72   93

# %%
df.cp.value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
pd.crosstab(df.sex,df.cp)
# Out:
# cp     0   1   2   3
# sex
# 0     39  18  35   4
# 1    104  32  52  19

# %%
pd.crosstab(df.target,df.cp)

#type 0 cp huda more than 70% chance xaina heart disease hudaina
# type 1 cp huda chaii there is 80% chance to have heart disease
#
# Out:
# cp        0   1   2   3
# target
# 0       104   9  18   7
# 1        39  41  69  16

# %%
import matplotlib.pyplot as plt

# %%
pd.crosstab(df.target,df.sex).plot(kind = 'bar')
plt.title("heart disease")
plt.xlabel( '1: disease 0: no disease')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
pd.crosstab(df.target,df.sex).plot(kind = 'bar', figsize = (10,6), color = ['pink','blue'])
plt.title("heart disease")
plt.xlabel( '1: disease 0: no disease')
plt.ylabel('count')
plt.legend(['female','male'])
plt.xticks(rotation = 50)
# Out:
# (array([0, 1]), [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
pd.crosstab(df.target,df.sex).plot(kind = 'bar', color = ['pink','blue'])
plt.title("heart disease")
plt.xlabel( '1: disease 0: no disease')
plt.ylabel('count')
plt.legend(['female','male'])

# %%
pd.crosstab(df.target,df.cp).plot(kind = 'bar', figsize = (10,6), color = ['pink','blue','yellow','green'])
plt.title("heart disease")
plt.xlabel( '1: disease 0: no disease')
plt.ylabel('count')
plt.legend(['cp0','cp1','cp2','cp3'])

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# df.clumns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.thal.value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
pd.crosstab(df.thal,df.target)
# Out:
# target   0    1
# thal
# 0        1    1
# 1       12    6
# 2       36  130
# 3       89   28

# %%
pd.crosstab(df.target,df.thal).plot(kind = 'bar')
plt.title('Heart disease with thal')
# Out:
# Text(0.5, 1.0, 'Heart disease with thal')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("heart-disease.csv")
df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df1.thalach.value_counts()
# Out:
# 162    11
# 160     9
# 163     9
# 152     8
# 173     8
#        ..
# 202     1
# 184     1
# 121     1
# 192     1
# 90      1
# Name: thalach, Length: 91, dtype: int64

# %%
df1.age[df1.target == 1]
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 160    56
# 161    55
# 162    41
# 163    38
# 164    38
# Name: age, Length: 165, dtype: int64

# %%
df1.age[df1.target == 1].value_counts()
# Out:
# 54    10
# 51     9
# 41     9
# 52     9
# 44     8
# 57     7
# 42     7
# 58     7
# 45     6
# 53     6
# 64     6
# 43     5
# 59     5
# 56     5
# 65     4
# 62     4
# 46     4
# 66     4
# 50     4
# 48     4
# 55     3
# 60     3
# 47     3
# 39     3
# 67     3
# 63     3
# 71     3
# 49     3
# 37     2
# 34     2
# 35     2
# 69     2
# 68     2
# 38     2
# 40     1
# 29     1
# 61     1
# 74     1
# 76     1
# 70     1
# Name: age, dtype: int64

# %%
plt.figure()
plt.scatter(df1.age[df1.target == 1],df1.thalach[df1.target == 1])

# %%
plt.figure()
plt.scatter(df1.age[df1.target == 1],df1.thalach[df1.target == 1],color = 'red')
plt.scatter(df1.age[df1.target == 0],df1.thalach[df1.target ==0],color = 'green')
plt.title("Heart disease reltion to age and thalach")
plt.xlabel("Age")
plt.ylabel("Max heart rate")
plt.legend(['Disease','No disease'])

# %%
df1.age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.cp.unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
pd.crosstab(df1.cp,df1.target).plot(kind = 'bar')
# Out:
# <Axes: xlabel='cp'>

# %%
df1.corr()
#correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...
