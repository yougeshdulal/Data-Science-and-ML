# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
str1="""
It boasts Hollywood royalty such as Martin Scorsese, Robert De Niro and Leonardo DiCaprio, 
was backed to the tune of $200m by tech behemoth Apple.
It has earned the kind of reviews that generate Oscar buzz.

But Killers of the Flower Moon, a western true-crime thriller about the systematic killing of Osage Nation members for their oil-rich land in the 1920s, is generating mixed feelings and opinions among Native American communities.

Killers of the Flower Moon feature: Martin Scorsese behind the scenes with Lily Gladstone
‘Who wasn’t complicit?’ How Martin Scorsese won the trust of the Osage Nation
Read more
Devery Jacobs, an Indigenous actor who played Elora in the TV drama Reservation Dogs, posted on social media X, formerly known as Twitter: “Being Native, watching this movie was fucking hellfire. Imagine the worst atrocities committed against (your) ancestors, then having to sit (through) a movie explicitly filled with them, with the only respite being 30 minute long scenes of murderous white guys talking about/planning the killings.”
"""

# %%
# sent_tokenize use garera para lai sentence ma split garum

# %%
sent_tokenize(str1)
# Out:
# ['\nIt boasts Hollywood royalty such as Martin Scorsese, Robert De Niro and Leonardo DiCaprio, \nwas backed to the tune of $200m by tech behemoth Apple.',
#  'It has earned the kind of reviews that generate Oscar buzz.',
#  'But Killers of the Flower Moon, a western true-crime thriller about the systematic killing of Osage Nation members for their oil-rich land in the 1920s, is generating mixed feelings and opinions among Native American communities.',
#  'Killers of the Flower Moon feature: Martin Scorsese behind the scenes with Lily Gladstone\n‘Who wasn’t complicit?’ How Martin Scorsese won the trust of the Osage Nation\nRead more\nDevery Jacobs, an Indigenous actor who played Elora in the TV drama Reservation Dogs, posted on social media X, formerly known as Twitter: “Being Native, watching this movie was fucking hellfire.',
# ...

# %%
# word wise garda
word_tokenize(str1)
# Out:
# ['It',
#  'boasts',
#  'Hollywood',
#  'royalty',
#  'such',
#  'as',
#  'Martin',
#  'Scorsese',
#  ',',
#  'Robert',
#  'De',
#  'Niro',
#  'and',
#  'Leonardo',
#  'DiCaprio',
#  ',',
#  'was',
#  'backed',
#  'to',
#  'the',
#  'tune',
#  'of',
#  '$',
#  '200m',
#  'by',
#  'tech',
#  'behemoth',
#  'Apple',
#  '.',
#  'It',
#  'has',
#  'earned',
#  'the',
#  'kind',
#  'of',
#  'reviews',
#  'that',
#  'generate',
#  'Oscar',
#  'buzz',
#  '.',
#  'But',
#  'Killers',
#  'of',
#  'the',
#  'Flower',
#  'Moon',
#  ',',
#  'a',
#  'western',
#  'true-crime',
#  'thriller',
#  'about',
#  'the',
#  'systematic',
#  'killing',
#  'of',
#  'Osage',
#  'Nation',
#  'members',
#  'for',
#  'their',
#  'oil-rich',
#  'land',
#  'in',
#  'the',
#  '1920s',
#  ',',
#  'is',
#  'generating',
#  'mixed',
#  'feelings',
#  'and',
#  'opinions',
#  'among',
#  'Native',
#  'American',
#  'communities',
#  '.',
#  'Killers',
#  'of',
#  'the',
#  'Flower',
#  'Moon',
#  'feature',
#  ':',
# ...

# %%
# nltk le 's',''s',',' etc lai word mancha raicha
# aba stop words filtering ma jam
# words that you want to ignore, so you filter them out of your text when you’re processing it
# in a as etc lai hataucha praye

# %%
word_filter = word_tokenize(str1)

# %%
word_filter
# Out:
# ['It',
#  'boasts',
#  'Hollywood',
#  'royalty',
#  'such',
#  'as',
#  'Martin',
#  'Scorsese',
#  ',',
#  'Robert',
#  'De',
#  'Niro',
#  'and',
#  'Leonardo',
#  'DiCaprio',
#  ',',
#  'was',
#  'backed',
#  'to',
#  'the',
#  'tune',
#  'of',
#  '$',
#  '200m',
#  'by',
#  'tech',
#  'behemoth',
#  'Apple',
#  '.',
#  'It',
#  'has',
#  'earned',
#  'the',
#  'kind',
#  'of',
#  'reviews',
#  'that',
#  'generate',
#  'Oscar',
#  'buzz',
#  '.',
#  'But',
#  'Killers',
#  'of',
#  'the',
#  'Flower',
#  'Moon',
#  ',',
#  'a',
#  'western',
#  'true-crime',
#  'thriller',
#  'about',
#  'the',
#  'systematic',
#  'killing',
#  'of',
#  'Osage',
#  'Nation',
#  'members',
#  'for',
#  'their',
#  'oil-rich',
#  'land',
#  'in',
#  'the',
#  '1920s',
#  ',',
#  'is',
#  'generating',
#  'mixed',
#  'feelings',
#  'and',
#  'opinions',
#  'among',
#  'Native',
#  'American',
#  'communities',
#  '.',
#  'Killers',
#  'of',
#  'the',
#  'Flower',
#  'Moon',
#  'feature',
#  ':',
# ...

# %%
stop_words_list = set(stopwords.words("english"))

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words_list = set(stopwords.words("english"))

# %%
stop_words_list
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
len(word_filter)
# Out:
# 196

# %%
list_filtered = []
for i in word_filter:
    if i.casefold() not in stop_words_list:
        list_filtered.append(i)

# %%
len(list_filtered)
# Out:
# 131

# %%
# stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
# PorterStemmer() bata stemmer banam aba
stemmer = PorterStemmer()

# %%
test_str = """
there are working class people driving the vision and reason of society. They have been helping
struggles reach the success.There's a dream revolving around the norm that says,"are we there yet?" These are exciting moments in the history of never dying mankind
"""

# %%
tok_words = word_tokenize(test_str)

# %%
tok_words
# Out:
# ['there',
#  'are',
#  'working',
#  'class',
#  'people',
#  'driving',
#  'the',
#  'vision',
#  'and',
#  'reason',
#  'of',
#  'society',
#  '.',
#  'They',
#  'have',
#  'been',
#  'helping',
#  'struggles',
#  'reach',
#  'the',
#  'success.There',
#  "'s",
#  'a',
#  'dream',
#  'revolving',
#  'around',
#  'the',
#  'norm',
#  'that',
#  'says',
#  ',',
#  "''",
#  'are',
#  'we',
#  'there',
#  'yet',
#  '?',
#  "''",
#  'These',
#  'are',
#  'exciting',
#  'moments',
#  'in',
#  'the',
#  'history',
#  'of',
#  'never',
#  'dying',
#  'mankind']

# %%
stemmed_words = [stemmer.stem(i) for i in tok_words]

# %%
stemmed_words
# Out:
# ['there',
#  'are',
#  'work',
#  'class',
#  'peopl',
#  'drive',
#  'the',
#  'vision',
#  'and',
#  'reason',
#  'of',
#  'societi',
#  '.',
#  'they',
#  'have',
#  'been',
#  'help',
#  'struggl',
#  'reach',
#  'the',
#  'success.ther',
#  "'s",
#  'a',
#  'dream',
#  'revolv',
#  'around',
#  'the',
#  'norm',
#  'that',
#  'say',
#  ',',
#  "''",
#  'are',
#  'we',
#  'there',
#  'yet',
#  '?',
#  "''",
#  'these',
#  'are',
#  'excit',
#  'moment',
#  'in',
#  'the',
#  'histori',
#  'of',
#  'never',
#  'die',
#  'mankind']

# %%
test_str
# Out:
# '\nthere are working class people drving the vision and reason of society. They have been helping\nstruggles reach the success.There\'s a dream revolving around the norm that says,"are we there yet?" These are exciting moments in the history of never dying mankind\n'

# %%
word_pos = nltk.pos_tag(tok_words)

# %%
word_pos
# Out:
# [('there', 'EX'),
#  ('are', 'VBP'),
#  ('working', 'VBG'),
#  ('class', 'NN'),
#  ('people', 'NNS'),
#  ('drving', 'VBG'),
#  ('the', 'DT'),
#  ('vision', 'NN'),
#  ('and', 'CC'),
#  ('reason', 'NN'),
#  ('of', 'IN'),
#  ('society', 'NN'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('helping', 'VBG'),
#  ('struggles', 'NNS'),
#  ('reach', 'VBP'),
#  ('the', 'DT'),
#  ('success.There', 'NN'),
#  ("'s", 'POS'),
#  ('a', 'DT'),
#  ('dream', 'NN'),
#  ('revolving', 'VBG'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('norm', 'NN'),
#  ('that', 'WDT'),
#  ('says', 'VBZ'),
#  (',', ','),
#  ("''", "''"),
#  ('are', 'VBP'),
#  ('we', 'PRP'),
#  ('there', 'EX'),
#  ('yet', 'RB'),
#  ('?', '.'),
#  ("''", "''"),
#  ('These', 'DT'),
#  ('are', 'VBP'),
#  ('exciting', 'VBG'),
#  ('moments', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('history', 'NN'),
#  ('of', 'IN'),
#  ('never', 'RB'),
#  ('dying', 'VBG'),
#  ('mankind', 'NN')]

# %%
# Lemmatizing
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("dwarves")
# Out:
# 'dwarf'
