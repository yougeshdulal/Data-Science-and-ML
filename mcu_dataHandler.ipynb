# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('mcu_box_office.csv')

# %%
data
# Out:
#                                   movie_title  mcu_phase release_date  \
# 0                                    Iron Man          1     5/2/2008
# 1                         The Incredible Hulk          1    6/13/2008
# 2                                  Iron Man 2          1     5/7/2010
# 3                                        Thor          1     5/6/2011
# 4          Captain America: The First Avenger          1    7/22/2011
# 5                                The Avengers          1     5/4/2012
# 6                                  Iron Man 3          2     5/3/2013
# 7                        Thor: The Dark World          2    11/8/2013
# 8         Captain America: The Winter Soldier          2     4/4/2014
# 9                     Guardians of the Galaxy          2     8/1/2014
# 10                    Avengers: Age of Ultron          2     5/1/2015
# 11                                    Ant-Man          2    7/17/2015
# ...

# %%
data.columns
# Out:
# Index(['movie_title', 'mcu_phase', 'release_date', 'tomato_meter',
#        'audience_score', 'movie_duration', 'production_budget',
#        'opening_weekend', 'domestic_box_office', 'worldwide_box_office'],
#       dtype='object')

# %%
data[['tomato_meter','audience_score']]
# Out:
#     tomato_meter  audience_score
# 0             94              91
# 1             67              70
# 2             72              71
# 3             77              76
# 4             79              75
# 5             91              91
# 6             79              78
# 7             66              75
# 8             90              92
# 9             92              92
# 10            76              83
# 11            83              85
# 12            90              89
# 13            89              86
# 14            85              87
# 15            92              87
# 16            93              87
# 17            96              79
# 18            85              91
# 19            87              81
# 20            79              45
# 21            94              90
# 22            90              95
# 23            79              91
# 24            91              98
# 25            47              78
# 26            93              98

# %%
data.head(7)[['tomato_meter','audience_score']]
# Out:
#    tomato_meter  audience_score
# 0            94              91
# 1            67              70
# 2            72              71
# 3            77              76
# 4            79              75
# 5            91              91
# 6            79              78

# %%
data
# Out:
#                                   movie_title  mcu_phase release_date  \
# 0                                    Iron Man          1     5/2/2008
# 1                         The Incredible Hulk          1    6/13/2008
# 2                                  Iron Man 2          1     5/7/2010
# 3                                        Thor          1     5/6/2011
# 4          Captain America: The First Avenger          1    7/22/2011
# 5                                The Avengers          1     5/4/2012
# 6                                  Iron Man 3          2     5/3/2013
# 7                        Thor: The Dark World          2    11/8/2013
# 8         Captain America: The Winter Soldier          2     4/4/2014
# 9                     Guardians of the Galaxy          2     8/1/2014
# 10                    Avengers: Age of Ultron          2     5/1/2015
# 11                                    Ant-Man          2    7/17/2015
# ...

# %%
data_7 = data[['tomato_meter','audience_score']]

# %%
data_7.head(8)
# Out:
#    tomato_meter  audience_score
# 0            94              91
# 1            67              70
# 2            72              71
# 3            77              76
# 4            79              75
# 5            91              91
# 6            79              78
# 7            66              75

# %%
data_7.plot()
# Out:
# <Axes: >

# %%
data_7.plot(kind='bar')
# Out:
# <Axes: >

# %%
data_7.columns
# Out:
# Index(['tomato_meter', 'audience_score'], dtype='object')

# %%
data_7['tomato_meter']
# Out:
# 0     94
# 1     67
# 2     72
# 3     77
# 4     79
# 5     91
# 6     79
# 7     66
# 8     90
# 9     92
# 10    76
# 11    83
# 12    90
# 13    89
# 14    85
# 15    92
# 16    93
# 17    96
# 18    85
# 19    87
# 20    79
# 21    94
# 22    90
# 23    79
# 24    91
# 25    47
# 26    93
# Name: tomato_meter, dtype: int64

# %%
data_7['tomato_meter'].plot()
# Out:
# <Axes: >

# %%
sns.scatterplot(data=data_7,x='tomato_meter',y='audience_score')
# Out:
# <Axes: xlabel='tomato_meter', ylabel='audience_score'>

# %%
data_7
# Out:
#     tomato_meter  audience_score
# 0             94              91
# 1             67              70
# 2             72              71
# 3             77              76
# 4             79              75
# 5             91              91
# 6             79              78
# 7             66              75
# 8             90              92
# 9             92              92
# 10            76              83
# 11            83              85
# 12            90              89
# 13            89              86
# 14            85              87
# 15            92              87
# 16            93              87
# 17            96              79
# 18            85              91
# 19            87              81
# 20            79              45
# 21            94              90
# 22            90              95
# 23            79              91
# 24            91              98
# 25            47              78
# 26            93              98

# %%
data.columns
# Out:
# Index(['movie_title', 'mcu_phase', 'release_date', 'tomato_meter',
#        'audience_score', 'movie_duration', 'production_budget',
#        'opening_weekend', 'domestic_box_office', 'worldwide_box_office'],
#       dtype='object')

# %%
data_n7 = data.drop(columns=['mcu_phase', 'release_date','movie_duration', 'production_budget',
       'opening_weekend', 'domestic_box_office', 'worldwide_box_office'])

# %%
data_n7
# Out:
#                                   movie_title  tomato_meter  audience_score
# 0                                    Iron Man            94              91
# 1                         The Incredible Hulk            67              70
# 2                                  Iron Man 2            72              71
# 3                                        Thor            77              76
# 4          Captain America: The First Avenger            79              75
# 5                                The Avengers            91              91
# 6                                  Iron Man 3            79              78
# 7                        Thor: The Dark World            66              75
# 8         Captain America: The Winter Soldier            90              92
# 9                     Guardians of the Galaxy            92              92
# 10                    Avengers: Age of Ultron            76              83
# ...

# %%
data_new = data.drop(columns=['movie_title','mcu_phase', 'release_date','movie_duration', 'production_budget',
       'opening_weekend', 'domestic_box_office', 'worldwide_box_office'])

# %%
data_new
# Out:
#     tomato_meter  audience_score
# 0             94              91
# 1             67              70
# 2             72              71
# 3             77              76
# 4             79              75
# 5             91              91
# 6             79              78
# 7             66              75
# 8             90              92
# 9             92              92
# 10            76              83
# 11            83              85
# 12            90              89
# 13            89              86
# 14            85              87
# 15            92              87
# 16            93              87
# 17            96              79
# 18            85              91
# 19            87              81
# 20            79              45
# 21            94              90
# 22            90              95
# 23            79              91
# 24            91              98
# 25            47              78
# 26            93              98

# %%
sns.histplot(data=data_new['tomato_meter'])
# Out:
# <Axes: xlabel='tomato_meter', ylabel='Count'>

# %%
sns.histplot(data=data_new['tomato_meter'],kde=True)
# Out:
# <Axes: xlabel='tomato_meter', ylabel='Count'>

# %%
plt.pie(data_new['tomato_meter'].head(5))
# Out:
# ([<matplotlib.patches.Wedge at 0x1641fd12d10>,
# ...
#  [Text(0.7979627596468291, 0.7571363379318264, ''),
#   Text(-0.5163315736629176, 0.9712886831621047, ''),
#   Text(-1.0991033056577928, -0.04440634517850722, ''),
#   Text(-0.3534081240569828, -1.0416826281792955, ''),
#   Text(0.8836109783804981, -0.6551577206180655, '')])

# %%
plt.pie(data_new['tomato_meter'].head(5),labels=data['movie_title'].head(5))
# Out:
# ([<matplotlib.patches.Wedge at 0x1641d3bb910>,
# ...
#  [Text(0.7979627596468291, 0.7571363379318264, 'Iron Man'),
#   Text(-0.5163315736629176, 0.9712886831621047, 'The Incredible Hulk'),
#   Text(-1.0991033056577928, -0.04440634517850722, 'Iron Man 2'),
#   Text(-0.3534081240569828, -1.0416826281792955, 'Thor'),
#   Text(0.8836109783804981, -0.6551577206180655, 'Captain America: The First Avenger')])

# %%
plt.pie(data_new['tomato_meter'].head(5),labels=data['movie_title'].head(5),colors=['red','blue','lightgreen','yellow','pink'])
# Out:
# ([<matplotlib.patches.Wedge at 0x16420402290>,
# ...
#  [Text(0.7979627596468291, 0.7571363379318264, 'Iron Man'),
#   Text(-0.5163315736629176, 0.9712886831621047, 'The Incredible Hulk'),
#   Text(-1.0991033056577928, -0.04440634517850722, 'Iron Man 2'),
#   Text(-0.3534081240569828, -1.0416826281792955, 'Thor'),
#   Text(0.8836109783804981, -0.6551577206180655, 'Captain America: The First Avenger')])

# %%
plt.pie(data_new['tomato_meter'].head(5),labels=data['movie_title'].head(5),colors=['red','blue','green','yellow','pink'],explode=[0.2,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x16426856290>,
# ...
#  [Text(0.9430468977644344, 0.8947974902830677, 'Iron Man'),
#   Text(-0.5163315736629176, 0.9712886831621047, 'The Incredible Hulk'),
#   Text(-1.0991033056577928, -0.04440634517850722, 'Iron Man 2'),
#   Text(-0.3534081240569828, -1.0416826281792955, 'Thor'),
#   Text(0.8836109783804981, -0.6551577206180655, 'Captain America: The First Avenger')])
