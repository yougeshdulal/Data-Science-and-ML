# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('fandango_scrape.csv')
df
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 505                      Valiyavan (2015)    0.0     0.0      0
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 509                            Zarafa (1)    0.0     0.0      0
#
# [510 rows x 4 columns]

# %%
df.info()  # count rows etcetera
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    510 non-null    object
#  1   STARS   510 non-null    float64
#  2   RATING  510 non-null    float64
#  3   VOTES   510 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 16.1+ KB

# %%
df.describe()  # statistical information
# Out:
#             STARS      RATING         VOTES
# count  510.000000  510.000000    510.000000
# mean     3.532353    3.351765   1134.364706
# std      1.585616    1.512628   3809.952176
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.025000      2.000000
# 50%      4.000000    3.800000     17.500000
# 75%      4.500000    4.300000    183.500000
# max      5.000000    5.000000  34846.000000

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES'], dtype='object')

# %%
df['FILM']
# Out:
# 0               Fifty Shades of Grey (2015)
# 1                     Jurassic World (2015)
# 2                    American Sniper (2015)
# 3                          Furious 7 (2015)
# 4                         Inside Out (2015)
#                        ...
# 505                        Valiyavan (2015)
# 506              WWE SummerSlam 2015 (2015)
# 507         Yagavarayinum Naa Kaakka (2015)
# 508    Yesterday, Today and Tomorrow (1964)
# 509                              Zarafa (1)
# Name: FILM, Length: 510, dtype: object

# %%
df['RATING']
# Out:
# 0      3.9
# 1      4.5
# 2      4.8
# 3      4.8
# 4      4.5
#       ...
# 505    0.0
# 506    0.0
# 507    0.0
# 508    0.0
# 509    0.0
# Name: RATING, Length: 510, dtype: float64

# %%
plt.plot(df['FILM'].head(3),df['RATING'].head(3), marker='o')

# %%
sns.scatterplot(data = df.head(10),x='FILM',y='RATING')
# Out:
# <Axes: xlabel='FILM', ylabel='RATING'>

# %%
sns.scatterplot(data = df.head(10),x='FILM',y='RATING', hue='RATING')
# Out:
# <Axes: xlabel='FILM', ylabel='RATING'>

# %%
sns.regplot(data=df.head(),x='STARS',y='RATING')
# Out:
# <Axes: xlabel='STARS', ylabel='RATING'>

# %%
data = pd.read_csv('application_record.csv')
data
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
data['NAME_EDUCATION_TYPE']
# Out:
# 0                      Higher education
# 1                      Higher education
# 2         Secondary / secondary special
# 3         Secondary / secondary special
# 4         Secondary / secondary special
#                       ...
# 438552    Secondary / secondary special
# 438553    Secondary / secondary special
# 438554                 Higher education
# 438555    Secondary / secondary special
# 438556    Secondary / secondary special
# Name: NAME_EDUCATION_TYPE, Length: 438557, dtype: object

# %%
data['CNT_CHILDREN']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 438552    0
# 438553    0
# 438554    0
# 438555    0
# 438556    0
# Name: CNT_CHILDREN, Length: 438557, dtype: int64

# %%
dengue 
15       30
17       11
25       250
31       900
# Out:
#   Cell In[29], line 2
#     15       300
#              ^
# SyntaxError: invalid syntax

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()
sns.scatterplot(data=df,x='FILM',y='RATING')
# Out:
# <Axes: xlabel='FILM', ylabel='RATING'>

# %%
sns.relplot(
    data=df,
    x="FILM", y="RATING",
    hue="RATING", style="STARS",
)
