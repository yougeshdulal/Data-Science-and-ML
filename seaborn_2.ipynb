# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('fandango_scrape.csv')
df
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 505                      Valiyavan (2015)    0.0     0.0      0
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 509                            Zarafa (1)    0.0     0.0      0
#
# [510 rows x 4 columns]

# %%
df['RATING']
# Out:
# 0      3.9
# 1      4.5
# 2      4.8
# 3      4.8
# 4      4.5
#       ...
# 505    0.0
# 506    0.0
# 507    0.0
# 508    0.0
# 509    0.0
# Name: RATING, Length: 510, dtype: float64

# %%
df['VOTES']
# Out:
# 0      34846
# 1      34390
# 2      34085
# 3      33538
# 4      15749
#        ...
# 505        0
# 506        0
# 507        0
# 508        0
# 509        0
# Name: VOTES, Length: 510, dtype: int64

# %%
sns.scatterplot(y='VOTES',x='RATING',data=df)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.scatterplot(y='VOTES',x='RATING',data=df, s= 200)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.scatterplot(y='VOTES',x='RATING',data=df, style = 'STARS', hue = 'VOTES')
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.scatterplot(x='STARS',y='RATING',data=df)
# Out:
# <Axes: xlabel='STARS', ylabel='RATING'>

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(y='VOTES',x='RATING',data=df, hue = 'VOTES')
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.boxplot(x='RATING',y='VOTES',data=df)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.barplot(x='RATING',y='VOTES',data=df)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.barplot(x='RATING',y='VOTES',data=df.head(10))
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.boxplot(x='RATING',y='VOTES',data=df.head(30))
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.boxenplot(x='RATING',y='VOTES',data=df.head(30))
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
n = df['VOTES']
n.sum()
# Out:
# 578526

# %%
df['RATING']
# Out:
# 0      3.9
# 1      4.5
# 2      4.8
# 3      4.8
# 4      4.5
#       ...
# 505    0.0
# 506    0.0
# 507    0.0
# 508    0.0
# 509    0.0
# Name: RATING, Length: 510, dtype: float64

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES'], dtype='object')

# %%
df = pd.read_csv('application_record.csv')
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df = pd.read_csv('credit_record.csv')
df
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df = pd.read_csv('application_record.csv')

# %%
df.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
# plt.figure(figsize=(12,4),alpha=0.2)
sns.scatterplot(y='AMT_INCOME_TOTAL', x='DAYS_BIRTH', data= df, alpha = 0.2)
# Out:
# <Axes: xlabel='DAYS_BIRTH', ylabel='AMT_INCOME_TOTAL'>

# %%
sns.scatterplot(y='AMT_INCOME_TOTAL', x='DAYS_BIRTH', data= df.head(500), alpha = 0.2)
# Out:
# <Axes: xlabel='DAYS_BIRTH', ylabel='AMT_INCOME_TOTAL'>
